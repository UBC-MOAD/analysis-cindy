# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import numpy as np
import copy
import os
import glob
from mpl_toolkits.basemap import cm,addcyclic,Basemap, shiftgrid
% matplotlib inline

# %%
nc_filename=glob.glob('*ptrc*.nc')
print("found *.nc file: \n{}".format(nc_filename))
# Out:
# found *.nc file:
# ['ORCA2_1m_00010101_00011231_ptrc_T.nc', 'ORCA2_1y_00010101_00011231_ptrc_T.nc']

# %%
ptrc=nc.Dataset(nc_filename[0])
print ptrc.variables
# Out:
# OrderedDict([(u'nav_lon', <netCDF4.Variable object at 0x7fd385a9dcc8>), (u'nav_lat', <netCDF4.Variable object at 0x7fd385a9db98>), (u'deptht', <netCDF4.Variable object at 0x7fd385aa15a8>), (u'time_counter', <netCDF4.Variable object at 0x7fd385aa1640>), (u'time_counter_bnds', <netCDF4.Variable object at 0x7fd385aa16d8>), (u'DIC', <netCDF4.Variable object at 0x7fd385aa1770>), (u'Alkalini', <netCDF4.Variable object at 0x7fd385aa1808>), (u'O2', <netCDF4.Variable object at 0x7fd385aa18a0>), (u'NCHL', <netCDF4.Variable object at 0x7fd385aa1938>), (u'DCHL', <netCDF4.Variable object at 0x7fd385aa19d0>), (u'DOC', <netCDF4.Variable object at 0x7fd385aa1a68>), (u'Fer', <netCDF4.Variable object at 0x7fd385aa1b00>), (u'NO3', <netCDF4.Variable object at 0x7fd385aa1b98>)])

# %%
nav_lon=ptrc.variables['nav_lon'][:]
nav_lat=ptrc.variables['nav_lat'][:]
DOC=ptrc.variables['DOC'][:]
DIC=ptrc.variables['DIC'][:]
O2=ptrc.variables['O2'][:]
DCHL=ptrc.variables['DCHL'][:]
NCHL=ptrc.variables['NCHL'][:]
Alkalini=ptrc.variables['Alkalini'][:]

# %%
print nav_lat.shape
print DOC[0,0,:,:].shape
print('Latitude {} ~ {}'.format(np.min(nav_lon), np.max(nav_lon)))
print('Longitude {} ~ {}'.format(np.min(nav_lat), np.max(nav_lat)))
# Out:
# (149, 182)
# (149, 182)
# Latitude -179.750701904 ~ 180.0
# Longitude -78.1905822754 ~ 89.613899231

# %%
lonlim=[-180, 180]
latlim=[-78, 89]

# %%
# create figure and axes instances
fig = plt.figure(figsize=(9,9))
ax = fig.add_axes([0.1,0.1,0.8,0.8])

# create Basemap instance.
m = Basemap(projection='npstere',boundinglat=53,lon_0=0,resolution='l')
m.drawcoastlines()
m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-80.,81.,15.),labels=[1, 0, 0, 0])
m.drawmeridians(np.arange(-180.,181.,20.),labels=[0, 0, 0, 1])

x, y = m(nav_lon, nav_lat)
clev=np.arange(20, 40, 2.5)
cs = m.contourf(x,y,DOC[1,1,:,:],cmap=plt.cm.YlGn)
cbar = m.colorbar(cs,location='right',pad="2%")
plt.title("DOC")
plt.show()

# %%
# create figure and axes instances
fig = plt.figure(figsize=(9,9))
ax = fig.add_axes([0.1,0.1,0.8,0.8])

# create Basemap instance.
m = Basemap(projection='npstere',boundinglat=53,lon_0=0,resolution='l')
m.drawcoastlines()
m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-80.,81.,15.),labels=[1, 0, 0, 0])
m.drawmeridians(np.arange(-180.,181.,20.),labels=[0, 0, 0, 1])

x, y = m(nav_lon, nav_lat)
clev=np.arange(20, 40, 2.5)
cs = m.contourf(x,y,DIC[1,1,:,:],cmap=plt.cm.bone)
cbar = m.colorbar(cs,location='right',pad="2%")
plt.title("DIC")
plt.show()

# %%
# create figure and axes instances
fig = plt.figure(figsize=(9,9))
ax = fig.add_axes([0.1,0.1,0.8,0.8])

# create Basemap instance.
m = Basemap(projection='npstere',boundinglat=53,lon_0=0,resolution='l')
m.drawcoastlines()
m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-80.,81.,15.),labels=[1, 0, 0, 0])
m.drawmeridians(np.arange(-180.,181.,20.),labels=[0, 0, 0, 1])

x, y = m(nav_lon, nav_lat)
clev=np.arange(20, 40, 2.5)
cs = m.contourf(x,y,O2[1,1,:,:],cmap=plt.cm.PuOr)
cbar = m.colorbar(cs,location='right',pad="2%")
plt.title("O2")
plt.show()

# %%
# create figure and axes instances
fig = plt.figure(figsize=(9,9))
ax = fig.add_axes([0.1,0.1,0.8,0.8])

# create Basemap instance.
m = Basemap(projection='npstere',boundinglat=53,lon_0=0,resolution='l')
m.drawcoastlines()
m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-80.,81.,15.),labels=[1, 0, 0, 0])
m.drawmeridians(np.arange(-180.,181.,20.),labels=[0, 0, 0, 1])

x, y = m(nav_lon, nav_lat)
clev=np.arange(20, 40, 2.5)
cs = m.contourf(x,y,NCHL[1,1,:,:],cmap=plt.cm.summer)
cbar = m.colorbar(cs,location='right',pad="2%")
plt.title("NCHL")
plt.show()

# %%
# create figure and axes instances
fig = plt.figure(figsize=(9,9))
ax = fig.add_axes([0.1,0.1,0.8,0.8])

# create Basemap instance.
m = Basemap(projection='npstere',boundinglat=53,lon_0=0,resolution='l')
m.drawcoastlines()
m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-80.,81.,15.),labels=[1, 0, 0, 0])
m.drawmeridians(np.arange(-180.,181.,20.),labels=[0, 0, 0, 1])

x, y = m(nav_lon, nav_lat)
clev=np.arange(20, 40, 2.5)
cs = m.contourf(x,y,DCHL[1,1,:,:],cmap=plt.cm.YlOrRd)
cbar = m.colorbar(cs,location='right',pad="2%")
plt.title("DCHL")
plt.show()

# %%
# create figure and axes instances
fig = plt.figure(figsize=(9,9))
ax = fig.add_axes([0.1,0.1,0.8,0.8])

# create Basemap instance.
m = Basemap(projection='npstere',boundinglat=53,lon_0=0,resolution='l')
m.drawcoastlines()
m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-80.,81.,15.),labels=[1, 0, 0, 0])
m.drawmeridians(np.arange(-180.,181.,20.),labels=[0, 0, 0, 1])

x, y = m(nav_lon, nav_lat)
clev=np.arange(20, 40, 2.5)
cs = m.contourf(x,y,Alkalini[1,1,:,:],cmap=plt.cm.gist_earth)
cbar = m.colorbar(cs,location='right',pad="2%")
plt.title("Alkalini")
plt.show()
