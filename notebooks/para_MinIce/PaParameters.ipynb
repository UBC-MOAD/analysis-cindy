# %% [markdown]
# # Fit parameters

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## High Ice

# %%
# 1991 Arctic Expedition Stn 3
depth = [50, 500, 1000, 1850, 2850, 3850]
dissolved = [0.062, 0.216, 0.258, 0.539, 0.632, 0.622]
particulate = [0.007, 0.006, 0.007, 0.01, 0.013, 0.012]

pd = np.polyfit(depth[1:], dissolved[1:], 1)
pp = np.polyfit(depth[1:], particulate[1:], 1)
drange = np.arange(0, 4000, 50)

fig, ax = plt.subplots(1, 2, figsize=(10,5))
ax[0].plot(np.array(particulate), np.array(depth), 'o')
ax[0].plot(pp[1] + pp[0]*drange, drange)
ax[0].invert_yaxis()
ax[1].plot(dissolved, depth, 'o')
ax[1].plot(pd[1] + pd[0]*drange, drange)
ax[1].invert_yaxis()

# %%
Q = 0.00246
# Particulate Slope in v High ice
mP = pp[0]
S = Q/mP
print (S)
# Out:
# 1194.88015717

# %%
mD = pd[0]
kdOka = mD/mP
print (kdOka)
# Out:
# 65.643745907

# %%
'''input kd'''
kd=1.0

# %%
# if kd = 1.0
ka = kd/kdOka
print (ka)
# Out:
# 0.01523374369

# %%
# test result
P0 = pp[0]*500 + pp[1] 
print (Q/ka + kdOka*P0)
print (pd[0]*500 + pd[1])
# Out:
# 0.587592684443
# 0.249329108804

# %%
print (Q/ka + kdOka*P0)
difference = Q/ka + kdOka*P0 - (pd[0]*500 + pd[1])
print (difference)
P0f = P0 - difference/2/kdOka
# Out:
# 0.587592684443
# 0.338263575639

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))
ax[0].plot(np.array(particulate), np.array(depth), 'o')
ax[0].plot(pp[1] + pp[0]*drange, drange)
ax[0].invert_yaxis()

ax[1].plot(dissolved, depth, 'o')
ax[1].plot(pd[1] + pd[0]*drange, drange)
ax[1].invert_yaxis()

ax[0].plot(P0f + Q/S*(drange-500), drange)
ax[1].plot(Q/ka + P0f*kdOka + kdOka*Q/S*(drange-500), drange)
print (Q/((pp[1] - difference/2/kdOka)/500.))
# Out:
# 426.293786025

# %% [markdown]
# ## Low Ice

# %%
# 1991 Arctic Expedition Stn 2
depth = [1220, 2220, 3220, 4220]
dissolved = [0.161, 0.259, 0.349, 0.33]
particulate = [0.007, 0.012, 0.009, 0.014]
# 1991 Arctic Expedition Stn 1
depth = depth + [500, 1300, 2300, 3300, 4300]
dissolved = dissolved + [0.163, 0.213, 0.266, 0.362, 0.342]
particulate = particulate + [0.004, 0.005,0.009,0.006, 0.013]
# 1991 Arctic Expedition Stn 4
depth = depth + [500, 1180, 2180, 3180, 4180] # ignoring 50 m
dissolved = dissolved + [0.143, 0.2, 0.279, 0.266, 0.317] # 0.118
particulate = particulate + [0.006, 0.005, 0.009, 0.008, 0.011] # 0.015

pd = np.polyfit(depth, dissolved, 1)
pp = np.polyfit(depth, particulate, 1)
drange = np.arange(0, 4500, 50)

#fig, ax = plt.subplots(1, 2, figsize=(10,5))
#ax[0].plot(np.array(particulate), np.array(depth), 'o')
#ax[0].plot(pp[1] + pp[0]*drange, drange)
#ax[0].invert_yaxis()
#ax[1].plot(dissolved, depth, 'o')
#ax[1].plot(pd[1] + pd[0]*drange, drange)
#ax[1].invert_yaxis()

# %%
mP = pp[0]
S = Q/mP
print (S)
# Out:
# 1342.94716232

# %%
mD = pd[0]
kdOka = mD/mP
print (kdOka)
# Out:
# 27.7281386427

# %%
# if kd = 1.
ka = kd/kdOka
print (ka)
# Out:
# 0.0360644474873

# %%
print (Q/ka + kdOka*P0)
difference = Q/ka + kdOka*P0 - (pd[0]*500 + pd[1])
print (difference)
P0f = P0 - difference/2/kdOka
# Out:
# 0.248201122506
# 0.0847175914297

# %%
fig, ax = plt.subplots(1, 2, figsize=(10,5))
ax[0].plot(np.array(particulate), np.array(depth), 'o')
ax[0].plot(pp[1] + pp[0]*drange, drange)
ax[0].invert_yaxis()
ax[1].plot(dissolved, depth, 'o')
ax[1].plot(pd[1] + pd[0]*drange, drange)
ax[1].invert_yaxis()
ax[0].plot(P0f + Q/S*(drange-500), drange)
ax[1].plot(Q/ka + P0f*kdOka + kdOka*Q/S*(drange-500), drange)
print (Q/((pp[1] - difference/2/kdOka)/500.))
# Out:
# 496.276840141
