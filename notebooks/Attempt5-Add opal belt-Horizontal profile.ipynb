# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import numpy as np
import copy
import os
import glob
from mpl_toolkits.basemap import cm,addcyclic,Basemap, shiftgrid
% matplotlib inline

# %%
nc_filename=glob.glob('*.nc')
print("found *.nc file: \n{}".format(nc_filename))
# Out:
# found *.nc file:
# ['GYRE_5d_00010101_00011230_grid_W.nc', 'GYRE_5d_00010101_00011230_grid_T.nc', 'GYRE_5d_00010101_00011230_ptrc_T.nc', 'GYRE_00004320_restart_trc.nc', 'GYRE_5d_00010101_00011230_diad_T.nc', 'GYRE_5d_00010101_00011230_grid_V.nc', 'floats.nc', 'GYRE_5d_00010101_00011230_grid_U.nc', 'GYRE_00004320_restart.nc']

# %%
#W=nc.Dataset(nc_filename[0])
#T=nc.Dataset(nc_filename[1])
ptrc_T=nc.Dataset(nc_filename[2])
print ptrc_T.variables
# Out:
# OrderedDict([(u'nav_lon', <netCDF4.Variable object at 0x7f2a904e9348>), (u'nav_lat', <netCDF4.Variable object at 0x7f2a904e93e0>), (u'deptht', <netCDF4.Variable object at 0x7f2a904e9478>), (u'time_counter', <netCDF4.Variable object at 0x7f2a904e9510>), (u'time_counter_bnds', <netCDF4.Variable object at 0x7f2a904e95a8>), (u'TR_7', <netCDF4.Variable object at 0x7f2a904e9640>), (u'TR_8', <netCDF4.Variable object at 0x7f2a904e96d8>), (u'TR_9', <netCDF4.Variable object at 0x7f2a904e9770>), (u'TR_10', <netCDF4.Variable object at 0x7f2a904e9808>), (u'DET', <netCDF4.Variable object at 0x7f2a904e98a0>), (u'ZOO', <netCDF4.Variable object at 0x7f2a904e9938>), (u'PHY', <netCDF4.Variable object at 0x7f2a904e99d0>), (u'NO3', <netCDF4.Variable object at 0x7f2a904e9a68>), (u'NH4', <netCDF4.Variable object at 0x7f2a904e9b00>), (u'DOM', <netCDF4.Variable object at 0x7f2a904e9b98>)])

# %%
lat = ptrc_T.variables['nav_lat'][:]
lon = ptrc_T.variables['nav_lon'][:]
Dis_Pa = ptrc_T.variables['TR_7'][:]
Par_Pa = ptrc_T.variables['TR_9'][:]
Dis_Th = ptrc_T.variables['TR_8'][:]
Par_Th = ptrc_T.variables['TR_10'][:]
depth = ptrc_T.variables['deptht'][:]
print('Latitude {} ~ {}'.format(np.min(lat), np.max(lat)))
print('Longitude {} ~ {}'.format(np.min(lon), np.max(lon)))
print Dis_Pa[0,0].shape
# Out:
# Latitude 14.8450098038 ~ 49.8954620361
# Longitude -85.6740493774 ~ -50.6235961914
# (22, 32)

# %%
latlim=[10, 50]
lonlim=[-85, -48]

# %%
Dis_Pa = np.ma.masked_equal(Dis_Pa,0)
Dis_Th = np.ma.masked_equal(Dis_Th,0)
Par_Pa = np.ma.masked_equal(Par_Pa,0)
Par_Th = np.ma.masked_equal(Par_Th,0)
print('Dis_Pa {} ~ {}'.format(np.min(Dis_Pa), np.max(Dis_Pa)))
print('Dis_Th {} ~ {}'.format(np.min(Dis_Th), np.max(Dis_Th)))
print('Par_Pa {} ~ {}'.format(np.min(Par_Pa), np.max(Par_Pa)))
print('Par_Th {} ~ {}'.format(np.min(Par_Th), np.max(Par_Th)))
# Out:
# Dis_Pa 0.00138143333606 ~ 0.0608660429716
# Dis_Th 0.0144720617682 ~ 2.62224531174
# Par_Pa 2.82320634142e-05 ~ 0.235916465521
# Par_Th -0.00221098889597 ~ 0.711765706539

# %%
# panel 1
fig = plt.figure(figsize=(18,15))
ax = fig.add_subplot(221)

m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

#m.drawmapboundary(fill_color= 'white')
#m.drawcoastlines(color = 'black',linewidth= 0.5)
#m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[0,0,:, :], cmap='RdYlGn')

# colorbar on right
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of dissolved Pa [T=0,Layer=0]')

# panel 2
ax = fig.add_subplot(222)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[0,10, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of dissolved Pa [T=0,Layer=10]')

# panel 3
ax = fig.add_subplot(223)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[0,15, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of dissolved Pa [T=0,Layer=15]')

# panel 4
ax = fig.add_subplot(224)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[0,25, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of dissolved Pa [T=0,Layer=25]')

plt.show()

# %%
# panel 1
fig = plt.figure(figsize=(18,15))
ax = fig.add_subplot(221)

m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

#m.drawmapboundary(fill_color= 'white')
#m.drawcoastlines(color = 'black',linewidth= 0.5)
#m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[71,0,:, :], cmap='RdYlGn')

# colorbar on right
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of dissolved Pa [T=6,Layer=0]')

# panel 2
ax = fig.add_subplot(222)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[71,10, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of dissolved Pa [T=6,Layer=10]')

# panel 3
ax = fig.add_subplot(223)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[71,15, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of dissolved Pa [T=6,Layer=15]')

# panel 4
ax = fig.add_subplot(224)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[71,25, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of dissolved Pa [T=6,Layer=25]')

plt.show()

# %% [markdown]
# # Concentration of Particle Pa

# %%
# panel 1
fig = plt.figure(figsize=(18,15))
ax = fig.add_subplot(221)

m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

#m.drawmapboundary(fill_color= 'white')
#m.drawcoastlines(color = 'black',linewidth= 0.5)
#m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Par_Pa[0,0,:, :], cmap='RdYlGn')

# colorbar on right
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Particle Pa [T=0,Layer=0]')

# panel 2
ax = fig.add_subplot(222)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Par_Pa[0,10, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Particle Pa [T=0,Layer=10]')

# panel 3
ax = fig.add_subplot(223)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Par_Pa[0,15, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Particle Pa [T=0,Layer=15]')

# panel 4
ax = fig.add_subplot(224)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Par_Pa[0,25, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of particle Pa [T=0,Layer=25]')

plt.show()

# %%
# panel 1
fig = plt.figure(figsize=(18,15))
ax = fig.add_subplot(221)

m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

#m.drawmapboundary(fill_color= 'white')
#m.drawcoastlines(color = 'black',linewidth= 0.5)
#m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Par_Pa[71,0,:, :], cmap='RdYlGn')

# colorbar on right
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Particle Pa [T=71,Layer=0]')

# panel 2
ax = fig.add_subplot(222)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Par_Pa[71,10, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Particle Pa [T=71,Layer=10]')

# panel 3
ax = fig.add_subplot(223)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Par_Pa[71,15, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Particle Pa [T=71,Layer=15]')

# panel 4
ax = fig.add_subplot(224)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Par_Pa[71,25, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of particle Pa [T=71,Layer=25]')

plt.show()

# %% [markdown]
# # Concentration of Particle Pa/Th

# %%
# panel 1
fig = plt.figure(figsize=(18,15))
ax = fig.add_subplot(221)

m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

#m.drawmapboundary(fill_color= 'white')
#m.drawcoastlines(color = 'black',linewidth= 0.5)
#m.fillcontinents(color = '0.85')
m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[71,0,:, :]/Dis_Th[71,0,:,:], cmap='RdYlGn')

# colorbar on right
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Dis Pa/Th [T=71,Layer=0]')

# panel 2
ax = fig.add_subplot(222)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[71,10, :, :]/Dis_Th[71,10,:,:],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Dis Pa/Th [T=71,Layer=10]')

# panel 3
ax = fig.add_subplot(223)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[71,15, :, :]/Dis_Th[71,15,:,:],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Dis Pa/Th [T=71,Layer=15]')

# panel 4
ax = fig.add_subplot(224)

# create Basemap instance.
m=Basemap(projection='stere',\
            lat_1=30, lat_2=60,lat_0=(latlim[0]+latlim[1])/2, \
            lon_0=(lonlim[0]+lonlim[1])/2,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')

m.drawparallels(np.arange(-90, 91,10),labels=[1,0,0,0], color = '0.25',linewidth= 0.5)
m.drawmeridians(np.arange(-180,180,20), labels=[1,0,0,1],color = '0.25',linewidth= 0.5)

# compute map proj coordinates and draw the map
x, y = m(lon, lat) 
cs = m.pcolor(x,y,Dis_Pa[71,20, :, :]/Dis_Th[71,20, :, :],cmap='RdYlGn')

# colorbar on right.
cbar = m.colorbar(cs,location='right',pad="2%")
cbar.set_label('concentration')
plt.title('Concentration of Dis Pa/Th [T=71,Layer=20]')

plt.show()
